# %%
import matminer
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
mpkey = "2xTZjLYjRnj2NXjdNO2up1hd13UE1ugh"

# %%
from pymatgen.ext.matproj import MPRester #Using pymatgen to retrieve data
mpr = MPRester(mpkey)  #Initialize module with API key

# %%
df = pd.read_json("weichih_elastic.json")

# %%
run_info = list(df['elasticity']) #extract list of dictionaries
df_runinfo = pd.DataFrame(run_info).fillna(0).astype(int) #create new dataframe
df = pd.concat([df, df_runinfo], axis=1) #merge with original dataframe
df = df.drop('elasticity', axis=1)

# %%
df
# Out:
#       material_id full_formula  formation_energy_per_atom  G_Reuss  G_VRH  \
# 0        mp-10006    Tl1Ag1Te2                  -0.041182       17     13
# 1        mp-10018          Ac1                   0.033002       12     14
# 2      mp-1008601       Zr1Ag2                  -0.047356      -13     17
# 3      mp-1008617       Yb1Ag2                  -0.338535       14     18
# 4      mp-1008653        Ag1C1                   2.235059        9     11
# ...           ...          ...                        ...      ...    ...
# 13111   mp-980014       Tm1Th3                   0.046190       34     36
# 13112   mp-981210        Tl3V1                   0.512790       26     27
# 13113     mp-9924          Te2                   0.144380        1      8
# 13114     mp-9948        V5Te4                  -0.301741       58     30
# 13115   mp-999484        Y1Ti1                   0.364728       19     22
#
#        G_Voigt  G_Voigt_Reuss_Hill  K_Reuss  K_VRH  K_Voigt  \
# 0            8                  13       27     28       29
# 1           15                  14       24     24       24
# 2           48                  17      115    116      116
# 3           22                  18       54     54       54
# 4           12                  11      107    107      107
# ...        ...                 ...      ...    ...      ...
# 13111       39                  36       51     51       51
# 13112       27                  27      101    102      102
# 13113       15                   8      -15      4       22
# 13114        3                  30       50     50       51
# 13115       26                  22       29     29       29
#
#        K_Voigt_Reuss_Hill
# 0                      28
# 1                      24
# 2                     116
# 3                      54
# 4                     107
# ...                   ...
# 13111                  51
# 13112                 102
# 13113                   4
# 13114                  50
# 13115                  29
#
# [13116 rows x 11 columns]

# %%
# Initialize empty list for bad data with shear modulus
bad_data = []

# Begin loop over dataframe
for i in range(len(df)):
    # Define frequently used variables
    mat_id = df['material_id'].iloc[i] # use iloc to iteratively pull samples from the dataframe in the loop.
    gv = df['G_Voigt'].iloc[i]
    gr = df['G_Reuss'].iloc[i]
    gvrh = df['G_VRH'].iloc[i]
    
    if gv < 0.50 * gvrh or gr < 0.50 * gvrh:
        bad_data.append(mat_id)
    elif gv > 1.50 * gvrh or gr > 1.50 * gvrh:
        bad_data.append(mat_id)

for j in bad_data:
    df = df[df['material_id'] != j] # Remove bad data

# %%
# Initialize empty list for bad data with bulk modulus
# Begin loop over dataframe
for i in range(len(df)):
    # Define frequently used variables
    mat_id = df['material_id'].iloc[i] # use iloc to iteratively pull samples from the dataframe in the loop.
    kv = df['K_Voigt'].iloc[i]
    kr = df['K_Reuss'].iloc[i]
    kvrh = df['K_VRH'].iloc[i]
    
    if kv < 0.50 * kvrh or kr < 0.50 * kvrh:
        #print(f'Found bad data: {chemical_formula} k_vrh = {kvrh}, k_v = {kv}, k_r = {kr}')
        bad_data.append(mat_id)
    elif kv > 1.50 * kvrh or kr > 1.50 * kvrh:
        #print(f'Found bad data: {chemical_formula} k_vrh = {kvrh}, k_v = {kv}, k_r = {kr}')
        bad_data.append(mat_id)

for j in bad_data:
    df = df[df['material_id'] != j] # Remove bad data

# %%
df
# Out:
#       material_id full_formula  formation_energy_per_atom  G_Reuss  G_VRH  \
# 0        mp-10006    Tl1Ag1Te2                  -0.041182       17     13
# 1        mp-10018          Ac1                   0.033002       12     14
# 3      mp-1008617       Yb1Ag2                  -0.338535       14     18
# 4      mp-1008653        Ag1C1                   2.235059        9     11
# 6      mp-1008866     Na1Ag1O1                  -0.759677       18     21
# ...           ...          ...                        ...      ...    ...
# 13109   mp-979951        Yb3U1                   0.642829       27     20
# 13110   mp-979963       Yb3Ti1                   0.391097       13     14
# 13111   mp-980014       Tm1Th3                   0.046190       34     36
# 13112   mp-981210        Tl3V1                   0.512790       26     27
# 13115   mp-999484        Y1Ti1                   0.364728       19     22
#
#        G_Voigt  G_Voigt_Reuss_Hill  K_Reuss  K_VRH  K_Voigt  \
# 0            8                  13       27     28       29
# 1           15                  14       24     24       24
# 3           22                  18       54     54       54
# 4           12                  11      107    107      107
# 6           25                  21       59     59       59
# ...        ...                 ...      ...    ...      ...
# 13109       14                  20       10     10       11
# 13110       16                  14       21     21       21
# 13111       39                  36       51     51       51
# 13112       27                  27      101    102      102
# 13115       26                  22       29     29       29
#
#        K_Voigt_Reuss_Hill
# 0                      28
# 1                      24
# 3                      54
# 4                     107
# 6                      59
# ...                   ...
# 13109                  10
# 13110                  21
# 13111                  51
# 13112                 102
# 13115                  29
#
# [10809 rows x 11 columns]

# %%
df.drop(df[df['formation_energy_per_atom'] > 0.2].index, inplace = True) #removing compound with formation energy over 0.2 eV/atom, as they are generally not favorable

# %%
calc_hard = 0.92 * ((df['G_VRH']/df['K_VRH'])**1.137) * ((df['G_VRH'])**0.708)

# %%
df
# Out:
#       material_id full_formula  formation_energy_per_atom  G_Reuss  G_VRH  \
# 0        mp-10006    Tl1Ag1Te2                  -0.041182       17     13
# 1        mp-10018          Ac1                   0.033002       12     14
# 3      mp-1008617       Yb1Ag2                  -0.338535       14     18
# 6      mp-1008866     Na1Ag1O1                  -0.759677       18     21
# 7      mp-1008903    Mg1Ag1Sb1                  -0.228935        9     16
# ...           ...          ...                        ...      ...    ...
# 13102   mp-972088       Zr3Zn1                  -0.121853       31     38
# 13103   mp-972364          Yb3                   0.002530       10     10
# 13105   mp-977585       Zr3Tl1                  -0.118315       57     60
# 13106   mp-979011       Tm1Zr1                   0.064374       40     40
# 13111   mp-980014       Tm1Th3                   0.046190       34     36
#
#        G_Voigt  G_Voigt_Reuss_Hill  K_Reuss  K_VRH  K_Voigt  \
# 0            8                  13       27     28       29
# 1           15                  14       24     24       24
# 3           22                  18       54     54       54
# 6           25                  21       59     59       59
# 7           24                  16       76     76       76
# ...        ...                 ...      ...    ...      ...
# 13102       44                  38       94     94       94
# 13103       11                  10       15     15       15
# 13105       63                  60      121    121      121
# 13106       40                  40       70     70       70
# 13111       39                  36       51     51       51
#
#        K_Voigt_Reuss_Hill
# 0                      28
# 1                      24
# 3                      54
# 6                      59
# 7                      76
# ...                   ...
# 13102                  94
# 13103                  15
# 13105                 121
# 13106                  70
# 13111                  51
#
# [10541 rows x 11 columns]

# %%
from matminer.featurizers.conversions import StrToComposition
from matminer.featurizers.composition import Meredig

stc = StrToComposition() # MatMiner only interacts with PyMatgen objects to featurize, so a necessary step is to convert chem. formula to composition PyMatgen object
md = Meredig() # Class to calculate features as defined in Meredig et. al.

df = stc.featurize_dataframe(df, col_id='full_formula') # Create column in df with pymatgen composition for each sample, entitled 'composition'
df = md.featurize_dataframe(df, col_id='composition') # Create columns with features from Meredig et al. from the df's composition column
# Out:
# StrToComposition:   0%|          | 0/10541 [00:00<?, ?it/s]
# Meredig:   0%|          | 0/10541 [00:00<?, ?it/s]

# %%
df
# Out:
#       material_id full_formula  formation_energy_per_atom  G_Reuss  G_VRH  \
# 0        mp-10006    Tl1Ag1Te2                  -0.041182       17     13
# 1        mp-10018          Ac1                   0.033002       12     14
# 3      mp-1008617       Yb1Ag2                  -0.338535       14     18
# 6      mp-1008866     Na1Ag1O1                  -0.759677       18     21
# 7      mp-1008903    Mg1Ag1Sb1                  -0.228935        9     16
# ...           ...          ...                        ...      ...    ...
# 13102   mp-972088       Zr3Zn1                  -0.121853       31     38
# 13103   mp-972364          Yb3                   0.002530       10     10
# 13105   mp-977585       Zr3Tl1                  -0.118315       57     60
# 13106   mp-979011       Tm1Zr1                   0.064374       40     40
# 13111   mp-980014       Tm1Th3                   0.046190       34     36
#
#        G_Voigt  G_Voigt_Reuss_Hill  K_Reuss  K_VRH  K_Voigt  ...  \
# 0            8                  13       27     28       29  ...
# 1           15                  14       24     24       24  ...
# 3           22                  18       54     54       54  ...
# 6           25                  21       59     59       59  ...
# 7           24                  16       76     76       76  ...
# ...        ...                 ...      ...    ...      ...  ...
# 13102       44                  38       94     94       94  ...
# 13103       11                  10       15     15       15  ...
# 13105       63                  60      121    121      121  ...
# 13106       40                  40       70     70       70  ...
# 13111       39                  36       51     51       51  ...
#
#        range Electronegativity mean Electronegativity  \
# 0                         0.48               1.937500
# 1                         0.00               1.100000
# 3                         0.67               1.706667
# 6                         2.51               2.100000
# 7                         0.74               1.763333
# ...                        ...                    ...
# 13102                     0.32               1.410000
# 13103                     0.00               1.260000
# 13105                     0.29               1.402500
# 13106                     0.08               1.290000
# 13111                     0.05               1.287500
#
#        avg s valence electrons  avg p valence electrons  \
# 0                     1.750000                 2.250000
# 1                     2.000000                 0.000000
# 3                     1.333333                 0.000000
# 6                     1.333333                 1.333333
# 7                     1.666667                 1.000000
# ...                        ...                      ...
# 13102                 2.000000                 0.000000
# 13103                 2.000000                 0.000000
# 13105                 2.000000                 0.250000
# 13106                 2.000000                 0.000000
# 13111                 2.000000                 0.000000
#
#        avg d valence electrons  avg f valence electrons  \
# 0                    10.000000                 3.500000
# 1                     1.000000                 0.000000
# 3                     6.666667                 4.666667
# 6                     3.333333                 0.000000
# 7                     6.666667                 0.000000
# ...                        ...                      ...
# 13102                 4.000000                 0.000000
# 13103                 0.000000                14.000000
# 13105                 4.000000                 3.500000
# 13106                 1.000000                 6.500000
# 13111                 1.500000                 3.250000
#
#        frac s valence electrons  frac p valence electrons  \
# 0                      0.100000                  0.128571
# 1                      0.666667                  0.000000
# 3                      0.105263                  0.000000
# 6                      0.222222                  0.222222
# 7                      0.178571                  0.107143
# ...                         ...                       ...
# 13102                  0.333333                  0.000000
# 13103                  0.125000                  0.000000
# 13105                  0.205128                  0.025641
# 13106                  0.210526                  0.000000
# 13111                  0.296296                  0.000000
#
#        frac d valence electrons  frac f valence electrons
# 0                      0.571429                  0.200000
# 1                      0.333333                  0.000000
# 3                      0.526316                  0.368421
# 6                      0.555556                  0.000000
# 7                      0.714286                  0.000000
# ...                         ...                       ...
# 13102                  0.666667                  0.000000
# 13103                  0.000000                  0.875000
# 13105                  0.410256                  0.358974
# 13106                  0.105263                  0.684211
# 13111                  0.222222                  0.481481
#
# [10541 rows x 132 columns]

# %%
df.drop(columns=["G_Voigt_Reuss_Hill", "K_Voigt_Reuss_Hill"],inplace=True) #removing unnecessary extra columns
df
# Out:
#       material_id full_formula  formation_energy_per_atom  G_Reuss  G_VRH  \
# 0        mp-10006    Tl1Ag1Te2                  -0.041182       17     13
# 1        mp-10018          Ac1                   0.033002       12     14
# 3      mp-1008617       Yb1Ag2                  -0.338535       14     18
# 6      mp-1008866     Na1Ag1O1                  -0.759677       18     21
# 7      mp-1008903    Mg1Ag1Sb1                  -0.228935        9     16
# ...           ...          ...                        ...      ...    ...
# 13102   mp-972088       Zr3Zn1                  -0.121853       31     38
# 13103   mp-972364          Yb3                   0.002530       10     10
# 13105   mp-977585       Zr3Tl1                  -0.118315       57     60
# 13106   mp-979011       Tm1Zr1                   0.064374       40     40
# 13111   mp-980014       Tm1Th3                   0.046190       34     36
#
#        G_Voigt  K_Reuss  K_VRH  K_Voigt   composition  ...  \
# 0            8       27     28       29  (Tl, Ag, Te)  ...
# 1           15       24     24       24          (Ac)  ...
# 3           22       54     54       54      (Yb, Ag)  ...
# 6           25       59     59       59   (Na, Ag, O)  ...
# 7           24       76     76       76  (Mg, Ag, Sb)  ...
# ...        ...      ...    ...      ...           ...  ...
# 13102       44       94     94       94      (Zr, Zn)  ...
# 13103       11       15     15       15          (Yb)  ...
# 13105       63      121    121      121      (Zr, Tl)  ...
# 13106       40       70     70       70      (Tm, Zr)  ...
# 13111       39       51     51       51      (Tm, Th)  ...
#
#        range Electronegativity  mean Electronegativity  \
# 0                         0.48                1.937500
# 1                         0.00                1.100000
# 3                         0.67                1.706667
# 6                         2.51                2.100000
# 7                         0.74                1.763333
# ...                        ...                     ...
# 13102                     0.32                1.410000
# 13103                     0.00                1.260000
# 13105                     0.29                1.402500
# 13106                     0.08                1.290000
# 13111                     0.05                1.287500
#
#        avg s valence electrons  avg p valence electrons  \
# 0                     1.750000                 2.250000
# 1                     2.000000                 0.000000
# 3                     1.333333                 0.000000
# 6                     1.333333                 1.333333
# 7                     1.666667                 1.000000
# ...                        ...                      ...
# 13102                 2.000000                 0.000000
# 13103                 2.000000                 0.000000
# 13105                 2.000000                 0.250000
# 13106                 2.000000                 0.000000
# 13111                 2.000000                 0.000000
#
#        avg d valence electrons  avg f valence electrons  \
# 0                    10.000000                 3.500000
# 1                     1.000000                 0.000000
# 3                     6.666667                 4.666667
# 6                     3.333333                 0.000000
# 7                     6.666667                 0.000000
# ...                        ...                      ...
# 13102                 4.000000                 0.000000
# 13103                 0.000000                14.000000
# 13105                 4.000000                 3.500000
# 13106                 1.000000                 6.500000
# 13111                 1.500000                 3.250000
#
#        frac s valence electrons  frac p valence electrons  \
# 0                      0.100000                  0.128571
# 1                      0.666667                  0.000000
# 3                      0.105263                  0.000000
# 6                      0.222222                  0.222222
# 7                      0.178571                  0.107143
# ...                         ...                       ...
# 13102                  0.333333                  0.000000
# 13103                  0.125000                  0.000000
# 13105                  0.205128                  0.025641
# 13106                  0.210526                  0.000000
# 13111                  0.296296                  0.000000
#
#        frac d valence electrons  frac f valence electrons
# 0                      0.571429                  0.200000
# 1                      0.333333                  0.000000
# 3                      0.526316                  0.368421
# 6                      0.555556                  0.000000
# 7                      0.714286                  0.000000
# ...                         ...                       ...
# 13102                  0.666667                  0.000000
# 13103                  0.000000                  0.875000
# 13105                  0.410256                  0.358974
# 13106                  0.105263                  0.684211
# 13111                  0.222222                  0.481481
#
# [10541 rows x 130 columns]

# %%
df = df.assign(hardness=calc_hard) # Adding calculated hardness to dataframe as a column

# %%
df
# Out:
#       material_id full_formula  formation_energy_per_atom  G_Reuss  G_VRH  \
# 0        mp-10006    Tl1Ag1Te2                  -0.041182       17     13
# 1        mp-10018          Ac1                   0.033002       12     14
# 3      mp-1008617       Yb1Ag2                  -0.338535       14     18
# 6      mp-1008866     Na1Ag1O1                  -0.759677       18     21
# 7      mp-1008903    Mg1Ag1Sb1                  -0.228935        9     16
# ...           ...          ...                        ...      ...    ...
# 13102   mp-972088       Zr3Zn1                  -0.121853       31     38
# 13103   mp-972364          Yb3                   0.002530       10     10
# 13105   mp-977585       Zr3Tl1                  -0.118315       57     60
# 13106   mp-979011       Tm1Zr1                   0.064374       40     40
# 13111   mp-980014       Tm1Th3                   0.046190       34     36
#
#        G_Voigt  K_Reuss  K_VRH  K_Voigt   composition  ...  \
# 0            8       27     28       29  (Tl, Ag, Te)  ...
# 1           15       24     24       24          (Ac)  ...
# 3           22       54     54       54      (Yb, Ag)  ...
# 6           25       59     59       59   (Na, Ag, O)  ...
# 7           24       76     76       76  (Mg, Ag, Sb)  ...
# ...        ...      ...    ...      ...           ...  ...
# 13102       44       94     94       94      (Zr, Zn)  ...
# 13103       11       15     15       15          (Yb)  ...
# 13105       63      121    121      121      (Zr, Tl)  ...
# 13106       40       70     70       70      (Tm, Zr)  ...
# 13111       39       51     51       51      (Tm, Th)  ...
#
#        mean Electronegativity  avg s valence electrons  \
# 0                    1.937500                 1.750000
# 1                    1.100000                 2.000000
# 3                    1.706667                 1.333333
# 6                    2.100000                 1.333333
# 7                    1.763333                 1.666667
# ...                       ...                      ...
# 13102                1.410000                 2.000000
# 13103                1.260000                 2.000000
# 13105                1.402500                 2.000000
# 13106                1.290000                 2.000000
# 13111                1.287500                 2.000000
#
#        avg p valence electrons  avg d valence electrons  \
# 0                     2.250000                10.000000
# 1                     0.000000                 1.000000
# 3                     0.000000                 6.666667
# 6                     1.333333                 3.333333
# 7                     1.000000                 6.666667
# ...                        ...                      ...
# 13102                 0.000000                 4.000000
# 13103                 0.000000                 0.000000
# 13105                 0.250000                 4.000000
# 13106                 0.000000                 1.000000
# 13111                 0.000000                 1.500000
#
#        avg f valence electrons  frac s valence electrons  \
# 0                     3.500000                  0.100000
# 1                     0.000000                  0.666667
# 3                     4.666667                  0.105263
# 6                     0.000000                  0.222222
# 7                     0.000000                  0.178571
# ...                        ...                       ...
# 13102                 0.000000                  0.333333
# 13103                14.000000                  0.125000
# 13105                 3.500000                  0.205128
# 13106                 6.500000                  0.210526
# 13111                 3.250000                  0.296296
#
#        frac p valence electrons  frac d valence electrons  \
# 0                      0.128571                  0.571429
# 1                      0.000000                  0.333333
# 3                      0.000000                  0.526316
# 6                      0.222222                  0.555556
# 7                      0.107143                  0.714286
# ...                         ...                       ...
# 13102                  0.000000                  0.666667
# 13103                  0.000000                  0.000000
# 13105                  0.025641                  0.410256
# 13106                  0.000000                  0.105263
# 13111                  0.000000                  0.222222
#
#        frac f valence electrons  hardness
# 0                      0.200000  2.363712
# 1                      0.000000  3.229192
# 3                      0.368421  2.041897
# 6                      0.000000  2.453713
# 7                      0.000000  1.114049
# ...                         ...       ...
# 13102                  0.000000  4.315610
# 13103                  0.875000  2.961911
# 13105                  0.358974  7.522287
# 13106                  0.684211  6.633031
# 13111                  0.481481  7.828141
#
# [10541 rows x 131 columns]

# %%
df[df['hardness'] > 200]
# Out:
#      material_id full_formula  formation_energy_per_atom  G_Reuss  G_VRH  \
# 3705    mp-23505     K2Te1Br6                  -1.023080        7      7
# 5599    mp-13925   Cs2Na1Y1F6                  -3.599160       20     21
# 5971   mp-989536   Cs2Li1N1F6                  -1.824214       33     33
# 6820     mp-7615     Rb3Tl1F6                  -2.635260        7      9
# 8583    mp-20457        In1P1                   0.027433       48     49
#
#       G_Voigt  K_Reuss  K_VRH  K_Voigt     composition  ...  \
# 3705        7        0      0        0     (K, Te, Br)  ...
# 5599       21        1      1        1  (Cs, Na, Y, F)  ...
# 5971       33        2      2        2  (Cs, Li, N, F)  ...
# 6820       10        0      0        0     (Rb, Tl, F)  ...
# 8583       51        2      2        2         (In, P)  ...
#
#       mean Electronegativity  avg s valence electrons  \
# 3705                2.388889                 1.777778
# 5599                2.761000                 1.700000
# 5971                2.948000                 1.700000
# 6820                2.796000                 1.700000
# 8583                1.985000                 2.000000
#
#       avg p valence electrons  avg d valence electrons  \
# 3705                 3.777778                 7.777778
# 5599                 3.000000                 0.100000
# 5971                 3.300000                 0.000000
# 6820                 3.100000                 1.000000
# 8583                 2.000000                 5.000000
#
#       avg f valence electrons  frac s valence electrons  \
# 3705                      0.0                  0.133333
# 5599                      0.0                  0.354167
# 5971                      0.0                  0.340000
# 6820                      1.4                  0.236111
# 8583                      0.0                  0.222222
#
#       frac p valence electrons  frac d valence electrons  \
# 3705                  0.283333                  0.583333
# 5599                  0.625000                  0.020833
# 5971                  0.660000                  0.000000
# 6820                  0.430556                  0.138889
# 8583                  0.222222                  0.555556
#
#       frac f valence electrons    hardness
# 3705                  0.000000         NaN
# 5599                  0.000000  253.094336
# 5971                  0.000000  264.956722
# 6820                  0.194444         NaN
# 8583                  0.000000  549.450395
#
# [5 rows x 131 columns]

# %%
nan_in_df = df[df['hardness'].isnull()] #Finding & removing any compounds with a hardness value NaN
print(nan_in_df)
# Out:
#      material_id full_formula  formation_energy_per_atom  G_Reuss  G_VRH  \
# 3705    mp-23505     K2Te1Br6              -1.023080e+00        7      7
# 6820     mp-7615     Rb3Tl1F6              -2.635260e+00        7      9
# 8156    mp-23907           H2               8.881784e-16        0      0
# 8263   mp-570752           H2               8.881784e-16        0      0
# 8285   mp-632250           H1               0.000000e+00        0      0
# 8289   mp-634659           H1               8.881784e-16        0      0
#
#       G_Voigt  K_Reuss  K_VRH  K_Voigt  composition  ...  \
# 3705        7        0      0        0  (K, Te, Br)  ...
# 6820       10        0      0        0  (Rb, Tl, F)  ...
# 8156        0        0      0        0          (H)  ...
# 8263        0        0      0        0          (H)  ...
# 8285        0        0      0        0          (H)  ...
# 8289        0        0      0        0          (H)  ...
#
#       mean Electronegativity  avg s valence electrons  \
# 3705                2.388889                 1.777778
# 6820                2.796000                 1.700000
# 8156                2.200000                 1.000000
# 8263                2.200000                 1.000000
# 8285                2.200000                 1.000000
# 8289                2.200000                 1.000000
#
#       avg p valence electrons  avg d valence electrons  \
# 3705                 3.777778                 7.777778
# 6820                 3.100000                 1.000000
# 8156                 0.000000                 0.000000
# 8263                 0.000000                 0.000000
# 8285                 0.000000                 0.000000
# 8289                 0.000000                 0.000000
#
#       avg f valence electrons  frac s valence electrons  \
# 3705                      0.0                  0.133333
# 6820                      1.4                  0.236111
# 8156                      0.0                  1.000000
# 8263                      0.0                  1.000000
# 8285                      0.0                  1.000000
# 8289                      0.0                  1.000000
#
#       frac p valence electrons  frac d valence electrons  \
# 3705                  0.283333                  0.583333
# 6820                  0.430556                  0.138889
# 8156                  0.000000                  0.000000
# 8263                  0.000000                  0.000000
# 8285                  0.000000                  0.000000
# 8289                  0.000000                  0.000000
#
#       frac f valence electrons  hardness
# 3705                  0.000000       NaN
# 6820                  0.194444       NaN
# 8156                  0.000000       NaN
# 8263                  0.000000       NaN
# 8285                  0.000000       NaN
# 8289                  0.000000       NaN
#
# [6 rows x 131 columns]

# %%
#Dropping due to NaN hardness calculation
df.drop(df[df['material_id'] == 'mp-23505' ].index, inplace = True)
df.drop(df[df['material_id'] == 'mp-7615' ].index, inplace = True)
df.drop(df[df['material_id'] == 'mp-23907' ].index, inplace = True)
df.drop(df[df['material_id'] == 'mp-570752' ].index, inplace = True)
df.drop(df[df['material_id'] == 'mp-632250' ].index, inplace = True)
df.drop(df[df['material_id'] == 'mp-634659' ].index, inplace = True)


#Dropping due to energy_above_hull > 0.2 eV
df.drop(df[df['material_id'] == 'mp-20457' ].index, inplace = True)

# %%
df
# Out:
#       material_id full_formula  formation_energy_per_atom  G_Reuss  G_VRH  \
# 0        mp-10006    Tl1Ag1Te2                  -0.041182       17     13
# 1        mp-10018          Ac1                   0.033002       12     14
# 3      mp-1008617       Yb1Ag2                  -0.338535       14     18
# 6      mp-1008866     Na1Ag1O1                  -0.759677       18     21
# 7      mp-1008903    Mg1Ag1Sb1                  -0.228935        9     16
# ...           ...          ...                        ...      ...    ...
# 13102   mp-972088       Zr3Zn1                  -0.121853       31     38
# 13103   mp-972364          Yb3                   0.002530       10     10
# 13105   mp-977585       Zr3Tl1                  -0.118315       57     60
# 13106   mp-979011       Tm1Zr1                   0.064374       40     40
# 13111   mp-980014       Tm1Th3                   0.046190       34     36
#
#        G_Voigt  K_Reuss  K_VRH  K_Voigt   composition  ...  \
# 0            8       27     28       29  (Tl, Ag, Te)  ...
# 1           15       24     24       24          (Ac)  ...
# 3           22       54     54       54      (Yb, Ag)  ...
# 6           25       59     59       59   (Na, Ag, O)  ...
# 7           24       76     76       76  (Mg, Ag, Sb)  ...
# ...        ...      ...    ...      ...           ...  ...
# 13102       44       94     94       94      (Zr, Zn)  ...
# 13103       11       15     15       15          (Yb)  ...
# 13105       63      121    121      121      (Zr, Tl)  ...
# 13106       40       70     70       70      (Tm, Zr)  ...
# 13111       39       51     51       51      (Tm, Th)  ...
#
#        mean Electronegativity  avg s valence electrons  \
# 0                    1.937500                 1.750000
# 1                    1.100000                 2.000000
# 3                    1.706667                 1.333333
# 6                    2.100000                 1.333333
# 7                    1.763333                 1.666667
# ...                       ...                      ...
# 13102                1.410000                 2.000000
# 13103                1.260000                 2.000000
# 13105                1.402500                 2.000000
# 13106                1.290000                 2.000000
# 13111                1.287500                 2.000000
#
#        avg p valence electrons  avg d valence electrons  \
# 0                     2.250000                10.000000
# 1                     0.000000                 1.000000
# 3                     0.000000                 6.666667
# 6                     1.333333                 3.333333
# 7                     1.000000                 6.666667
# ...                        ...                      ...
# 13102                 0.000000                 4.000000
# 13103                 0.000000                 0.000000
# 13105                 0.250000                 4.000000
# 13106                 0.000000                 1.000000
# 13111                 0.000000                 1.500000
#
#        avg f valence electrons  frac s valence electrons  \
# 0                     3.500000                  0.100000
# 1                     0.000000                  0.666667
# 3                     4.666667                  0.105263
# 6                     0.000000                  0.222222
# 7                     0.000000                  0.178571
# ...                        ...                       ...
# 13102                 0.000000                  0.333333
# 13103                14.000000                  0.125000
# 13105                 3.500000                  0.205128
# 13106                 6.500000                  0.210526
# 13111                 3.250000                  0.296296
#
#        frac p valence electrons  frac d valence electrons  \
# 0                      0.128571                  0.571429
# 1                      0.000000                  0.333333
# 3                      0.000000                  0.526316
# 6                      0.222222                  0.555556
# 7                      0.107143                  0.714286
# ...                         ...                       ...
# 13102                  0.000000                  0.666667
# 13103                  0.000000                  0.000000
# 13105                  0.025641                  0.410256
# 13106                  0.000000                  0.105263
# 13111                  0.000000                  0.222222
#
#        frac f valence electrons  hardness
# 0                      0.200000  2.363712
# 1                      0.000000  3.229192
# 3                      0.368421  2.041897
# 6                      0.000000  2.453713
# 7                      0.000000  1.114049
# ...                         ...       ...
# 13102                  0.000000  4.315610
# 13103                  0.875000  2.961911
# 13105                  0.358974  7.522287
# 13106                  0.684211  6.633031
# 13111                  0.481481  7.828141
#
# [10534 rows x 131 columns]

# %%
df.to_json('mp.json',default_handler = str)
